# %%
import numpy
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df_v= pd.read_csv("exp_corr.csv", encoding="shift-jis")
df_h= pd.read_csv("exp_corr_horizonal.csv", encoding="shift-jis")

# %%
df_corr=df[:25].corr()

# %%
#plt.figure()
sns.heatmap(df_corr, vmax=1, vmin=-1, center=0,annot=True)
#plt.savefig('a.png')

# %%
(df[0:5])
# Out:
#       part       time     ratio   q1   q2   q3   q4
# 0  mouthLR  38.933333  1.340661  2.0  1.0  3.0  2.0
# 1  mouthUD  39.583333  0.943913  5.0  5.0  5.0  1.0
# 2      NaN        NaN       NaN  NaN  NaN  NaN  NaN
# 3   browUD  35.733333  1.419401  5.0  5.0  4.0  2.0
# 4  smileRL  45.300000  0.971150  3.0  3.0  3.0  2.0

# %%
sns.heatmap(df[0:5].corr(), vmax=1, vmin=-1, center=0,annot=True)

# %%
(df[6:11])
# Out:
#        part       time     ratio   q1   q2   q3   q4
# 6   mouthLR  27.233333  0.997628  4.0  5.0  4.0  2.0
# 7   mouthUD  24.883333  0.599444  4.0  5.0  4.0  2.0
# 8       NaN        NaN       NaN  NaN  NaN  NaN  NaN
# 9    browUD  30.666667  2.453008  3.0  3.0  3.0  2.0
# 10  smileRL  34.700000  0.689522  4.0  5.0  4.0  2.0

# %%
sns.heatmap(df[6:11].corr(), vmax=1, vmin=-1, center=0,annot=True)

# %%
#df[12:17].corr()
df[12:17]
# Out:
#        part       time     ratio   q1   q2   q3   q4
# 12  mouthLR  46.733333  0.914738  2.0  4.0  4.0  3.0
# 13  mouthUD  55.400000  0.471794  2.0  5.0  4.0  2.0
# 14      NaN        NaN       NaN  NaN  NaN  NaN  NaN
# 15   browUD  38.766667  4.171319  2.0  4.0  4.0  4.0
# 16  smileRL  36.250000  1.088045  4.0  3.0  3.0  4.0

# %%
fig, axes = plt.subplots(nrows=2, ncols=4, figsize=(28, 16))
for i in range(4):
    sns.heatmap(df[i*6:i*6+5].corr(), vmax=1, vmin=-1, center=0,annot=True,ax=axes[0,i])

# %%
df_h
fig, axes = plt.subplots(nrows=2, ncols=4, figsize=(28, 16))
for i in range(4):
    sns.heatmap(df_h[i*6:i*6+5].corr(), vmax=1, vmin=-1, center=0,annot=True,ax=axes[0,i])

# %%
df_h
# Out:
#        part       time     ratio   q1   q2   q3   q4
# 0   mouthLR  35.270000  1.163988  5.0  2.0  4.0  3.0
# 1   mouthUD  27.480000  1.341703  4.0  5.0  4.0  2.0
# 2       NaN        NaN       NaN  NaN  NaN  NaN  NaN
# 3    browUD  35.270000  1.700028  5.0  5.0  4.0  1.0
# 4   smileRL  23.650000  0.815082  5.0  5.0  5.0  2.0
# 5       NaN        NaN       NaN  NaN  NaN  NaN  NaN
# 6   mouthLR  47.150000  0.961244  4.0  5.0  3.0  1.0
# 7   mouthUD  34.083333  0.892516  5.0  5.0  5.0  1.0
# 8       NaN        NaN       NaN  NaN  NaN  NaN  NaN
# 9    browUD  44.783333  2.848708  4.0  4.0  4.0  4.0
# 10  smileRL  33.950000  0.910453  4.0  3.0  4.0  1.0
# 11      NaN        NaN       NaN  NaN  NaN  NaN  NaN
# 12  mouthLR  33.316667  1.023547  2.0  5.0  3.0  4.0
# 13  mouthUD  42.366667  1.113916  2.0  3.0  2.0  3.0
# 14      NaN        NaN       NaN  NaN  NaN  NaN  NaN
# 15   browUD  43.916667  1.735980  1.0  4.0  2.0  2.0
# 16  smileRL  32.416667  1.047089  5.0  5.0  5.0  2.0
# ...

# %%
sns.heatmap(df[0:23].corr(), vmax=1, vmin=-1, center=0,annot=True)

# %%
sns.heatmap(df_h[0:23].corr(), vmax=1, vmin=-1, center=0,annot=True)

# %%
df_h
# Out:
#        part       time     ratio   q1   q2   q3   q4
# 0   mouthLR  35.270000  1.163988  5.0  2.0  4.0  3.0
# 1   mouthUD  27.480000  1.341703  4.0  5.0  4.0  2.0
# 2       NaN        NaN       NaN  NaN  NaN  NaN  NaN
# 3    browUD  35.270000  1.700028  5.0  5.0  4.0  1.0
# 4   smileRL  23.650000  0.815082  5.0  5.0  5.0  2.0
# 5       NaN        NaN       NaN  NaN  NaN  NaN  NaN
# 6   mouthLR  47.150000  0.961244  4.0  5.0  3.0  1.0
# 7   mouthUD  34.083333  0.892516  5.0  5.0  5.0  1.0
# 8       NaN        NaN       NaN  NaN  NaN  NaN  NaN
# 9    browUD  44.783333  2.848708  4.0  4.0  4.0  4.0
# 10  smileRL  33.950000  0.910453  4.0  3.0  4.0  1.0
# 11      NaN        NaN       NaN  NaN  NaN  NaN  NaN
# 12  mouthLR  33.316667  1.023547  2.0  5.0  3.0  4.0
# 13  mouthUD  42.366667  1.113916  2.0  3.0  2.0  3.0
# 14      NaN        NaN       NaN  NaN  NaN  NaN  NaN
# 15   browUD  43.916667  1.735980  1.0  4.0  2.0  2.0
# 16  smileRL  32.416667  1.047089  5.0  5.0  5.0  2.0
# ...
